# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Cas pratique n°1

# %%
site = "https://www.basketball-reference.com/leagues/NBA_2022_per_game.html"

response = requests.get(site)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
players = []
excluded_class = 'thead'

# Recupération des données 
for row in soup.find('tbody').find_all('tr')[1:-1]:
    if excluded_class not in row.get('class', []):
        player = []
        player.append(row.find('th').text)
        for j in row.find_all('td'):
            player.append(j.text)
        players.append(player)

# %%
# Recupération des colonnes
colonnes = [i.text for i in soup.find_all('tr')[0].find_all('th')]

# %%
# Création du DataFrame
df = pd.DataFrame(players, columns=colonnes)
df.drop(columns=['Awards'], inplace=True)
df.head()
# Out:
#   Rk                 Player Age Team Pos   G  GS    MP    FG   FGA  ...   FT%  \
# 0  2           LeBron James  37  LAL   C  56  56  37.2  11.4  21.8  ...  .756
# 1  3  Giannis Antetokounmpo  27  MIL  PF  67  67  32.9  10.3  18.6  ...  .722
# 2  4           Kevin Durant  33  BRK  PF  55  55  37.2  10.5  20.3  ...  .910
# 3  5            Luka Dončić  22  DAL  PG  65  65  35.4   9.9  21.6  ...  .744
# 4  6             Trae Young  23  ATL  PG  76  76  34.9   9.4  20.3  ...  .904
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.1  7.1   8.2  6.2  1.3  1.1  3.5  2.2  30.3
# 1  2.0  9.6  11.6  5.8  1.1  1.4  3.3  3.2  29.9
# 2  0.5  6.9   7.4  6.4  0.9  0.9  3.5  2.1  29.9
# 3  0.9  8.3   9.1  8.7  1.2  0.6  4.5  2.2  28.4
# 4  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
#
# [5 rows x 30 columns]

# %%
df.to_csv('data/cas_1/result_partie_1.csv', index=False)

# %% [markdown]
# ## Cas pratique n°2

# %%
site = "https://content.codecademy.com/courses/beautifulsoup/cacao/index.html"

response = requests.get(site)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
rows = []

for row in soup.find('table', id='cacaoTable').find_all('tr')[1:]:
    # Recupération des données
    rating = row.find('td', class_='Rating').text
    percent = row.find('td', class_='CocoaPercent').text

    row_data = [rating, percent]
    rows.append(row_data)

# %%
# Recupération des colonnes
rating = soup.find('table', id='cacaoTable').find('td', class_='Rating').text
percent = soup.find('table', id='cacaoTable').find('td', class_='CocoaPercent').attrs['class'][0]

colonnes = [rating, percent]

# %%
df = pd.DataFrame(rows, columns=colonnes)
df
# Out:
#      Rating CocoaPercent
# 0      3.75          63%
# 1      2.75          70%
# 2         3          70%
# 3       3.5          70%
# 4       3.5          70%
# ...     ...          ...
# 1790   3.75          70%
# 1791      3          65%
# 1792    3.5          65%
# 1793   3.25          62%
# 1794      3          65%
#
# [1795 rows x 2 columns]

# %%
df.to_csv('data/cas_2/result_partie_2.csv', index=False)

# %%
df.to_json('data/cas_2/result_partie_2_index.json', orient='index')
df.to_json('data/cas_2/result_partie_2_value.json', orient='values')
df.to_json('data/cas_2/result_partie_2_record.json', orient='records')

# %% [markdown]
# ## Cas pratique n°3

# %%
site = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops"

# %%
def get_laptop(site):
    response = requests.get(site)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = []

    for i in soup.find('div', class_='container test-site').find('div', class_='col-lg-9').find_all('div', class_='product-wrapper card-body'):
        title = i.find('a', class_='title').attrs['title']
        description = i.find('p', class_='description').text
        price = i.find('h4', class_='price').text[1:]

        row = [title, description, price]
        rows.append(row)
    
    colonnes = ['titre', 'description', 'prix']

    df = pd.DataFrame(rows, columns=colonnes)
    return df

# %%
df = get_laptop(site)
df
# Out:
#             titre                                        description     prix
# 0  Packard 255 G2  15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...   416.99
# 1   Aspire E1-510    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux   306.99
# 2  ThinkPad T540p   15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit  1178.99
# 3         ProBook    14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit   739.99
# 4   ThinkPad X240  12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...  1311.99
# 5  Aspire E1-572G  15.6", Core i5-4200U, 8GB, 1TB, Radeon R7 M265...   581.99

# %%
site = 'https://webscraper.io/test-sites/e-commerce/static/computers/tablets'

df_tablets = get_laptop(site)
df_tablets
# Out:
#               titre                                        description    prix
# 0    Lenovo IdeaTab                                 7" screen, Android   69.99
# 1       Acer Iconia                           7" screen, Android, 16GB   96.99
# 2     Asus MeMO Pad                            7" screen, Android, 8GB  102.99
# 3     Amazon Kindle                                    6" screen, wifi  103.99
# 4  iPad Mini Retina                     Wi-Fi + Cellular, 32GB, Silver  537.99
# 5    IdeaTab A3500L  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2   88.99

# %%
def get_laptop(site):
    response = requests.get(site)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = []

    for i in soup.find('div', class_='container test-site').find('div', class_='col-lg-9').find_all('div', class_='product-wrapper card-body'):
        title = i.find('a', class_='title').attrs['title']
        description = i.find('p', class_='description').text
        price = i.find('h4', class_='price').text[1:]
        rating = len(i.find('div', class_='ratings').find_all('span', class_='ws-icon ws-icon-star'))
        row = [title, description, price, rating]
        rows.append(row)
    
    colonnes = ['titre', 'description', 'prix', 'note']

    df = pd.DataFrame(rows, columns=colonnes)
    df['prix'] = df['prix'].astype('float')
    df['note'] = df['note'].astype('int')
    
    return df

# %%
df_response = pd.DataFrame()
for i in range(1,21):
    site = f'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page={i}'
    df_temp = get_laptop(site)

    # Concat le resultat 
    df_response = pd.concat([df_response, df_temp])

# %%
df_response
# Out:
#                                     titre  \
# 0                          Packard 255 G2
# 1                           Aspire E1-510
# 2                          ThinkPad T540p
# 3                                 ProBook
# 4                           ThinkPad X240
# ..                                    ...
# 4                    Lenovo ThinkPad T470
# 5          Lenovo ThinkPad Yoga 370 Black
# 0   Toshiba Portege X20W-D-10V Black/Blue
# 1       Asus ASUSPRO B9440UA-GV0279R Gray
# 2           Asus ROG Strix GL702VM-GC146T
#
#                                           description     prix  note
# 0   15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...   416.99     2
# 1     15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux   306.99     3
# 2    15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit  1178.99     1
# 3     14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit   739.99     4
# 4   12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...  1311.99     3
# ..                                                ...      ...   ...
# 4   Lenovo ThinkPad T470, 14" FHD IPS, Core i5-720...  1349.23     1
# 5   Lenovo ThinkPad Yoga 370 Black, 13.3" FHD IPS ...  1362.24     2
# 0   Toshiba Portege X20W-D-10V Black/Blue, 12.5" F...  1366.32     1
# 1   Asus ASUSPRO B9440UA-GV0279R Gray, 14" FHD, Co...  1381.13     1
# 2   Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core...  1399.00     3
#
# [117 rows x 4 columns]

# %%
# 1. Les 3 laptops les mieux notés
df_1 = df_response.nlargest(3, "note") 
df_1
# Out:
#             titre                                        description    prix  \
# 3         ProBook    14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit  739.99
# 3  Dell Vostro 15  Dell Vostro 15 (3568) Black, 15.6" FHD, Core i...  488.78
# 1   Aspire E1-510    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux  306.99
#
#    note
# 3     4
# 3     4
# 1     3

# %%
# 2. Les 3 laptops les moins bien notés
df_2 = df_response.nsmallest(3, 'note')
df_2
# Out:
#             titre                                        description     prix  \
# 2  ThinkPad T540p   15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit  1178.99
# 5  Aspire E1-572G  15.6", Core i5-4200U, 8GB, 1TB, Radeon R7 M265...   581.99
# 1        Pavilion      15.6", Core i5-4200U, 6GB, 750GB, Windows 8.1   609.99
#
#    note
# 2     1
# 5     1
# 1     1

# %%
# 3. Les 3 laptops les plus chers
df_3 = df_response.nlargest(3, "prix") 
df_3
# Out:
#            titre                                        description     prix  \
# 4  ThinkPad X240  12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...  1311.99
# 3    Dell XPS 13  13.3" Touch, Core i5-4210U, 8GB, 128GB SSD, Wi...  1281.99
# 4  ThinkPad X230  12.5", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pr...  1244.99
#
#    note
# 4     3
# 3     3
# 4     3

# %%
# 4. Les 3 laptops les moins chers
df_4 = df_response.nsmallest(3, "prix") 
df_4
# Out:
#                titre                                        description  \
# 1      Aspire E1-510    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
# 2  Asus VivoBook Max  Asus VivoBook Max X541NA-GQ041 Black Chocolate...
# 0     Packard 255 G2  15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...
#
#      prix  note
# 1  306.99     3
# 2  399.00     1
# 0  416.99     2

# %%
df_response = pd.DataFrame()
for i in range(1,5):
    site = f'https://webscraper.io/test-sites/e-commerce/static/computers/tablets?page={i}'
    df_temp = get_laptop(site)

    # Concat le resultat 
    df_response = pd.concat([df_response, df_temp])

# %%
df_response
# Out:
#               titre                                        description  \
# 0    Lenovo IdeaTab                                 7" screen, Android
# 1       Acer Iconia                           7" screen, Android, 16GB
# 2     Asus MeMO Pad                            7" screen, Android, 8GB
# 3     Amazon Kindle                                    6" screen, wifi
# 4  iPad Mini Retina                     Wi-Fi + Cellular, 32GB, Silver
# 5    IdeaTab A3500L  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2
# 0        Galaxy Tab                                        16GB, White
# 1   IdeaTab A3500-H  Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Andro...
# 2      Galaxy Tab 3                 7", 8GB, Wi-Fi, Android 4.2, White
# 3       Galaxy Note              12.2", 32GB, WiFi, Android 4.4, White
# 4        MeMO Pad 7           White, 7", Atom 1.2GHz, 8GB, Android 4.4
# 5      Galaxy Tab 4        LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black
# 0      Galaxy Tab 3                7", 8GB, Wi-Fi, Android 4.2, Yellow
# 1     Memo Pad HD 7            IPS, Dual-Core 1.2GHz, 8GB, Android 4.3
# 2  Galaxy Note 10.1                                 10.1", 32GB, Black
# 3   MeMo PAD FHD 10   White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2
# 4     IdeaTab S5000  Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, An...
# 5   Iconia B1-730HD      Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4
# 0     IdeaTab A8-50  Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2
# 1       Galaxy Note                 10.1", 3G, Android 4.0, Garnet Red
# 2    Apple iPad Air                                Wi-Fi, 64GB, Silver
#
#      prix  note
# 0   69.99     3
# 1   96.99     1
# 2  102.99     4
# 3  103.99     4
# 4  537.99     2
# 5   88.99     4
# 0  251.99     3
# 1  148.99     2
# 2   97.99     2
# 3  489.99     3
# 4  130.99     1
# 5  233.99     4
# 0  107.99     2
# 1  101.99     2
# 2  587.99     2
# 3  320.99     2
# 4  172.99     3
# 5   99.99     3
# 0  121.99     2
# 1  399.99     4
# 2  603.99     3

# %%
# 1. Les 3 tablettes les mieux notés
df_1 = df_response.nlargest(3, "note") 
df_1
# Out:
#             titre                                        description    prix  \
# 2   Asus MeMO Pad                            7" screen, Android, 8GB  102.99
# 3   Amazon Kindle                                    6" screen, wifi  103.99
# 5  IdeaTab A3500L  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2   88.99
#
#    note
# 2     4
# 3     4
# 5     4

# %%
# 2. Les 3 tablettes les moins bien notés
df_2 = df_response.nsmallest(3, 'note')
df_2
# Out:
#               titre                               description    prix  note
# 1       Acer Iconia                  7" screen, Android, 16GB   96.99     1
# 4        MeMO Pad 7  White, 7", Atom 1.2GHz, 8GB, Android 4.4  130.99     1
# 4  iPad Mini Retina            Wi-Fi + Cellular, 32GB, Silver  537.99     2

# %%
# 3. Les 3 talettes les plus chers
df_3 = df_response.nlargest(3, "prix") 
df_3
# Out:
#               titre                     description    prix  note
# 2    Apple iPad Air             Wi-Fi, 64GB, Silver  603.99     3
# 2  Galaxy Note 10.1              10.1", 32GB, Black  587.99     2
# 4  iPad Mini Retina  Wi-Fi + Cellular, 32GB, Silver  537.99     2

# %%
# 4. Les 3 tablettes les moins chers
df_4 = df_response.nsmallest(3, "prix") 
df_4
# Out:
#             titre                                        description   prix  \
# 0  Lenovo IdeaTab                                 7" screen, Android  69.99
# 5  IdeaTab A3500L  Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2  88.99
# 1     Acer Iconia                           7" screen, Android, 16GB  96.99
#
#    note
# 0     3
# 5     4
# 1     1
